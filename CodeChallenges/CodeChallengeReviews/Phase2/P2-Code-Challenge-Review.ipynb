# %% [markdown]
# # Assessment Review

# %% [markdown]
# The topics covered will be:
#
# 1. Normal Distributions
# 2. Statistical Tests
# 3. Bayesian Statistics
# 4. Linear Regression

# %% [markdown]
# ## Part 1: Normal Distributions

# %% [markdown]
# In this part, you will analyze hours of sleep for Freshman at a University. We know that the population distribution of hours of sleep for Freshman at the University is normally distributed with a mean of 6 and a standard deviation of 2.

# %% [markdown]
# ### Task 1: Create a numeric variable `z_eight` that contains the z-score for a Freshman that sleeps 8 hours

# %%
# Code here
mean = 6
std_dev = 2
threshold = 8
z_eight = (threshold-mean)/std_dev
z_eight
# Out:
# 1.0

# %% [markdown]
# ### Task 2: Create a numeric variable `over_eight` containing the approximate proportion of Freshman who get more than 8 hours of sleep

# %%
from scipy import stats
over_eight = 1 - stats.norm.cdf(z_eight)
over_eight
# Out:
# 0.15865525393145707

# %%
# Code here
from scipy.stats import norm
over_eight = 1 - norm.cdf(threshold, mean, std_dev)
over_eight
# Out:
# 0.15865525393145707

# %% [markdown]
# ### Task 3: Calculate a 95% confidence interval for the amount of sleep for one Freshman who sleeps 7 times with a mean of 5 hours and a standard deviation of 0.5 hours

# %% [markdown]
# ## __Need standard error for confidence interval__

# %%
# Code here
import scipy.stats as stats
import numpy as np

mu=5
std=0.5
n=7
se = std/np.sqrt(n)

stats.t.interval(alpha=0.95, df=n-1, loc=mu, scale=se)
# Out:
# (4.53757712628571, 5.46242287371429)

# %% [markdown]
# ### Task 4: Interpret the 95% Confidence Interval that you derived in the above question

# %% [markdown]
# Interpret:
#
# - Our 95% confidence interval is 4.53-5.46 hours of sleep. As in, 95% of the time the mean of this freshman's sleep habits will fall within this interval.

# %% [markdown]
# ## Part 2: Hypothesis Testing
#
# Let's make some hypotheses about cars!

# %% [markdown]
# ### Task 5: Set Up

# %%
# Imports - need pandas and matplotlib
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Import the auto-mpg csv from the data folder
df = pd.read_csv("data/auto-mpg.csv")

# %%
# Check the head of our data
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0         130    3504          12.0
# 1  15.0          8         350.0         165    3693          11.5
# 2  18.0          8         318.0         150    3436          11.0
# 3  16.0          8         304.0         150    3433          12.0
# 4  17.0          8         302.0         140    3449          10.5
#
#    model year  origin                   car name
# 0          70       1  chevrolet chevelle malibu
# 1          70       1          buick skylark 320
# 2          70       1         plymouth satellite
# 3          70       1              amc rebel sst
# 4          70       1                ford torino

# %%
# Check the info on our data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392 entries, 0 to 391
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           392 non-null    float64
#  1   cylinders     392 non-null    int64
#  2   displacement  392 non-null    float64
#  3   horsepower    392 non-null    int64
#  4   weight        392 non-null    int64
#  5   acceleration  392 non-null    float64
#  6   model year    392 non-null    int64
#  7   origin        392 non-null    int64
#  8   car name      392 non-null    object
# dtypes: float64(3), int64(5), object(1)
# memory usage: 27.7+ KB

# %%
# Describe the data
df.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  392.000000  392.000000    392.000000  392.000000   392.000000
# mean    23.445918    5.471939    194.411990  104.469388  2977.584184
# std      7.805007    1.705783    104.644004   38.491160   849.402560
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.000000    4.000000    105.000000   75.000000  2225.250000
# 50%     22.750000    4.000000    151.000000   93.500000  2803.500000
# 75%     29.000000    8.000000    275.750000  126.000000  3614.750000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model year      origin
# count    392.000000  392.000000  392.000000
# mean      15.541327   75.979592    1.576531
# std        2.758864    3.683737    0.805518
# min        8.000000   70.000000    1.000000
# 25%       13.775000   73.000000    1.000000
# 50%       15.500000   76.000000    1.000000
# 75%       17.025000   79.000000    2.000000
# max       24.800000   82.000000    3.000000

# %%
# Run this cell without changes to set up for the next set of questions

# Grabbing the median car weight
weight_median = df['weight'].median()

# Separating based on light cars and heavy cars
heavy_cars = df.loc[df['weight'] > weight_median].sample(n=100, random_state=42)
light_cars = df.loc[df['weight'] <= weight_median].sample(n=100, random_state=42)

# Plotting histograms for acceleration for both light and heavy cars
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

ax1.set_title('Sample of Heavy Cars')
ax1.set_xlabel('Acceleration')
ax1.set_ylabel('Frequency')
ax1.hist(heavy_cars['acceleration'], bins=12)

ax2.set_title('Sample of Light Cars')
ax2.set_xlabel('Acceleration')
ax2.set_ylabel('Frequency')
ax2.hist(light_cars['acceleration'], bins=12)
plt.show()

# %% [markdown]
# ### The Prompt:
#
# > Car manufacturers want to know if light cars accelerate faster than heavy cars.
#
# ### Task 6: Set up the null and alternative hypotheses for this test

# %% [markdown]
# **Null hypothesis:**
#
# - Light cars do not accelerate faster than heavy cars. They have equal acceleration speed or heavy cars are faster than light cars.
#
#
# **Alternative hypothesis:**
#
# - Light cars accelerate faster than heavy cars.

# %% [markdown]
# ### Task 7: Describe your Type 1 and Type 2 errors in this context

# %% [markdown]
# **Type I Error:**
#
# - False positive: concluded that light cars are faster than heavy cars in acceleration speed which is incorrect.
#
#
# **Type II Error:**
#
# - False negative: concluded that light cars accelerate faster than heavy cars but there is no evidence to support it.

# %% [markdown]
# ### Task 8: The Hypothesis Test!

# %% [markdown]
# ### 8a: Describe the type of test:

# %% [markdown]
# Description:
#
# - We have two categories of car, light and heavy, to test. We'll use a 2-sample independant t test to do so.

# %% [markdown]
# ### 8b: Run the test, using alpha = .05 and assuming that the samples have equal variance

# %%
light_cars
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 319  32.2          4         108.0          75    2265          15.2
# 269  23.2          4         156.0         105    2745          16.7
# 49   28.0          4         116.0          90    2123          14.0
# 181  25.0          4         116.0          81    2220          16.9
# 337  23.5          6         173.0         110    2725          12.6
# ..    ...        ...           ...         ...     ...           ...
# 29   27.0          4          97.0          88    2130          14.5
# 148  26.0          4         108.0          93    2391          15.5
# 240  21.5          4         121.0         110    2600          12.8
# 322  40.8          4          85.0          65    2110          19.2
# 14   24.0          4         113.0          95    2372          15.0
#
#      model year  origin               car name
# 319          80       3         toyota corolla
# 269          78       1       plymouth sapporo
# 49           71       2              opel 1900
# 181          76       2              opel 1900
# 337          81       1     chevrolet citation
# ..          ...     ...                    ...
# 29           71       3           datsun pl510
# 148          74       3                 subaru
# 240          77       2               bmw 320i
# 322          80       3             datsun 210
# 14           70       3  toyota corona mark ii
#
# [100 rows x 9 columns]

# %%
# Code here
import scipy.stats as stats
result = stats.ttest_ind(light_cars["acceleration"], heavy_cars["acceleration"], equal_var=True)
result.pvalue/2
# Out:
# 6.048220334084493e-07

# %% [markdown]
# ## ttst_ind takes in two series

# %% [markdown]
# ### 8c: Analyze your results: can you reject the null hypothesis?

# %% [markdown]
# Can you reject the null hypothesis?
#
# - With a p-value of near 0, far less than the alpha, we can reject the null. Light cars accelerate faster than heavy cars.

# %% [markdown]
# ## Part 3: Bayesian Statistics
#
# $$ P(A|B) = \dfrac{P(B|A)P(A)}{P(B)}$$

# %% [markdown]
# ### The Prompt:
# > In the second session of the 98th congress in 1984, a congressman voted 'No' on providing aid to El Salvador.
# >
# > Given that 60% of the congress were Democrats, 75% of whom voted 'No' for providing aid to El Salvador, and only 5% of Republicans voted 'No' to the proposal, what is the conditional probability that this individual is a Democrat?

# %% [markdown]
# ### Task 9: Calculate the probability

# %%
p_democrat = 0.6
p_nogivendemocrat = 0.75
p_nogivenrepublican = 0.05
p_no = p_nogivendemocrat*p_democrat + p_nogivenrepublican*(1-p_democrat)
p_no
# Out:
# 0.47

# %%
p_democratgivenno= (p_nogivendemocrat*p_democrat)/p_no
p_democratgivenno
# Out:
# 0.9574468085106382

# %% [markdown]
# **1. Which probability are we trying to find?**
#
#    - We are trying to determine the probablity of Democrat given voted "no".
#
#
# **2. Based on that, what other pieces do we need?**
#
#    - Ideally we need to know how much of Congress is Republicans, but we can assume 40% given 60% is Democrat
#    - We can use this value to determine the probability of any congressperson voting no
#
#
# **3. Result?**
#
#    - 95.7%

# %% [markdown]
# ## Part 4: Simple Linear Regression
#
# **BACK TO CARS**
#
# ### The Prompt:
#
# > Car manufacturers have asked us to predict how many miles per gallon a car can run based on the other variables we have in the data we're given.
#
# Sounds like a regression problem! But first let's further explore the data.

# %% [markdown]
# ### Task 10: Explore the Data Visually

# %%
import seaborn as sns

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0         130    3504          12.0
# 1    15.0          8         350.0         165    3693          11.5
# 2    18.0          8         318.0         150    3436          11.0
# 3    16.0          8         304.0         150    3433          12.0
# 4    17.0          8         302.0         140    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 387  27.0          4         140.0          86    2790          15.6
# 388  44.0          4          97.0          52    2130          24.6
# 389  32.0          4         135.0          84    2295          11.6
# 390  28.0          4         120.0          79    2625          18.6
# 391  31.0          4         119.0          82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# 1            70       1          buick skylark 320
# 2            70       1         plymouth satellite
# 3            70       1              amc rebel sst
# 4            70       1                ford torino
# ..          ...     ...                        ...
# 387          82       1            ford mustang gl
# 388          82       2                  vw pickup
# 389          82       1              dodge rampage
# 390          82       1                ford ranger
# 391          82       1                 chevy s-10
#
# [392 rows x 9 columns]

# %%
# Make a pairplot using seaborn to examine the relationships between variables
# Note - do this on the whole dataframe, not just independent variables
sns.pairplot(df, corner = True);

# %%
# Create a correlation heatmap as well, with seaborn plus the 'corr' function
sns.heatmap(df.corr(), annot=True);

# %% [markdown]
# ### Task 11: Explore your variables
#
# Look at both at the pairplot and the correlation heatmap - what are some trends you see? Any potential problems?
#
# Here, we expect you to look at what kinds of data you have. You may also want to discuss how the data is distributed. Analyze both the relationships between independent variables and the relationships between independent variables and your target/dependent variable (miles per gallon).

# %% [markdown]
# **Observations:**
#
# - There are a few categorical variables - model year, origin, car name, and possibly cylinders as well
# - Our independant numerical variables are displacement, horsepower, weight, acceleration though these also seem to be highly correlated to each other, which will make determining the relationship between these variables and mpg difficult.

# %% [markdown]
# ### Task 12: Pick one X variable and model
#
# Pick the variable you think would be best to use to predict MPG, and create, fit and summarize the output of a statsmodels OLS model!
#
# Set the summary output equal to `simple_model_summary`

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
# Either define X and y (if using OLS) or define your formula (if using ols)
# Make sure that if you use OLS to add a constant to your X!
y = df["mpg"]
X = df["weight"]
simple_model = sm.OLS(y, sm.add_constant(X)).fit()

# %%
simple_model_summary = simple_model.summary()
simple_model_summary
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.693
# Model:                            OLS   Adj. R-squared:                  0.692
# Method:                 Least Squares   F-statistic:                     878.8
# Date:                Thu, 09 Feb 2023   Prob (F-statistic):          6.02e-102
# Time:                        16:17:57   Log-Likelihood:                -1130.0
# No. Observations:                 392   AIC:                             2264.
# Df Residuals:                     390   BIC:                             2272.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         46.2165      0.799     57.867      0.000      44.646      47.787
# weight        -0.0076      0.000    -29.645      0.000      -0.008      -0.007
# ==============================================================================
# Omnibus:                       41.682   Durbin-Watson:                   0.808
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               60.039
# Skew:                           0.727   Prob(JB):                     9.18e-14
# Kurtosis:                       4.251   Cond. No.                     1.13e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.13e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ### Task 13: Interpret!

# %% [markdown]
# There are many things you could observe from this output, but I want especially for you to make an inference about the relationship between the X variable and MPG.
#
# - With an R-squared of 0.7, we have a pretty good fit but not a great one.
# - There is a statistically significant relationship between weight and mpg, as the p-value is extremely small, basically 0. This means we can reject the null that there's no relationship between the two variables.
# - The formula is mpg = 46.2165 - 0.0076(weight), meaning that if the car weights nothing it'll get a mean of 46 miles to the gallon. But for every increasing unit of weight, it'll get 0.0076 gallons less than 46.

# %% [markdown]
# ### Task 14: Model with all numeric X variables
#
# Create, fit and summarize the output of a statsmodels OLS model that has all of the possible X variables in our dataset!
#
# Set the summary output equal to `model_summary`

# %%
# Want to use 'cylinders', 'displacement', 'horsepower', 'weight' and 'acceleration'
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0         130    3504          12.0
# 1  15.0          8         350.0         165    3693          11.5
# 2  18.0          8         318.0         150    3436          11.0
# 3  16.0          8         304.0         150    3433          12.0
# 4  17.0          8         302.0         140    3449          10.5
#
#    model year  origin                   car name
# 0          70       1  chevrolet chevelle malibu
# 1          70       1          buick skylark 320
# 2          70       1         plymouth satellite
# 3          70       1              amc rebel sst
# 4          70       1                ford torino

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

y = df["mpg"]
X = df[['cylinders', 'displacement', 'horsepower', 'weight', 'acceleration']]
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = .33, random_state = 42)
lm = LinearRegression()
lm.fit(X_train,y_train)
print(lm.score(X_train, y_train))
print(lm.score(X_test, y_test))
# Out:
# 0.7322596761087244
# 0.6266775048775979

# %%
# Either define X and y (if using OLS) or define your formula (if using ols)
# Make sure that if you use OLS to add a constant to your X! 
y = df["mpg"]
X = df[['cylinders', 'displacement', 'horsepower', 'weight', 'acceleration']]
new_model = sm.OLS(y, sm.add_constant(X)).fit()

# %%
model_summary = new_model.summary()
model_summary
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.708
# Model:                            OLS   Adj. R-squared:                  0.704
# Method:                 Least Squares   F-statistic:                     186.9
# Date:                Thu, 09 Feb 2023   Prob (F-statistic):          9.82e-101
# Time:                        16:17:51   Log-Likelihood:                -1120.1
# No. Observations:                 392   AIC:                             2252.
# Df Residuals:                     386   BIC:                             2276.
# Df Model:                           5
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const           46.2643      2.669     17.331      0.000      41.016      51.513
# cylinders       -0.3979      0.411     -0.969      0.333      -1.205       0.409
# displacement -8.313e-05      0.009     -0.009      0.993      -0.018       0.018
# horsepower      -0.0453      0.017     -2.716      0.007      -0.078      -0.012
# weight          -0.0052      0.001     -6.351      0.000      -0.007      -0.004
# acceleration    -0.0291      0.126     -0.231      0.817      -0.276       0.218
# ==============================================================================
# Omnibus:                       38.561   Durbin-Watson:                   0.865
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               52.737
# Skew:                           0.706   Prob(JB):                     3.53e-12
# Kurtosis:                       4.111   Cond. No.                     3.87e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.87e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ### Task 15: Interpret!

# %%
# call_on_students(1)

# %% [markdown]
# Specifically, compare this model summary to your simple model's summary.
#
# - Our adjusted R-squared has only marginally improved, it's barely perceptible, meaning that adding these other variables might not be useful to our model.
# - The intecept remains effectively the same, indicating these other variables are not very influential, which we can see in how marginally they affect the mpg.
# - The most important variable seems to be displacement which has a coefficient of -831300, as in it works on y by almost 800,000.

# %% [markdown]
# Suppose a certain disease has an incidence rate of 0.1% (that is, it afflicts 0.1% of the population). A test has been devised to detect this disease. The test does not produce false negatives (that is, anyone who has the disease will test positive for it), but the false positive rate is 5% (that is, about 5% of people who take the test will test positive, even though they do not have the disease). Suppose a randomly selected person takes the test and tests positive. What is the probability that this person actually has the disease?

# %%
disease = 0.001
no_disease = .999
positivegivendisease = 1
positivegivenno_disease = 0.05

# %%
positive = positivegivendisease*disease + positivegivenno_disease*no_disease

# %%
diseasegivenpositive = (positivegivendisease * disease)/positive

# %%
diseasegivenpositive
# Out:
# 0.019801980198019802
